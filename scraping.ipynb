# %% [markdown]
# ## Import libraries
# Using BeautifulSoup to scrape data off of Ubisoft's Official Website and writing data to .csv file.
#
# Note: To get your user agent, search "What is my user agent" and copy the string given to you on the search page or visit [this](https://www.whatismybrowser.com/detect/what-is-my-user-agent/) website.

# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
from dotenv import load_dotenv
load_dotenv()

USER_AGENT = os.getenv("USER_AGENT")

# %% [markdown]
# Generate list of operator names to get description page for each of the operators

# %%
# List of all operator names in game
operator_names = [
    "lion",
    "amaru",
    "goyo",
    "nokk",
    "warden",
    "mozzie",
    "gridlock",
    "nomad",
    "kaid",
    "clash",
    "maverick",
    "maestro",
    "alibi",
    "finka",
    "vigil",
    "dokkaebi",
    "zofia",
    "ela",
    "ying",
    "lesion",
    "mira",
    "jackal",
    "hibana",
    "echo",
    "caveira",
    "capitao",
    "blackbeard",
    "valkyrie",
    "buck",
    "frost",
    "mute",
    "sledge",
    "smoke",
    "thatcher",
    "ash",
    "castle",
    "pulse",
    "thermite",
    "montagne",
    "twitch",
    "doc",
    "rook",
    "jager",
    "bandit",
    "blitz",
    "iq",
    "fuze",
    "glaz",
    "tachanka",
    "kapkan",
    "kali",
    "wamai",
    "iana",
    "oryx",
    "ace",
    "melusi",
    "zero",
    "aruni",
    "flores",
    "thunderbird",
    "osa",
    "thorn",
    "azami",
    "sens",
    "grim",
    "solis",
    "brava",
    "fenrir",
    "ram",
    "tubarao",
    "deimos",
    "striker",
    "sentry",
    "skopos",
]

# %% [markdown]
# ## Create functions to get operator properties from page
# Each operator info page has the same page structure so we can use class naming conventions and tags to get specific operator data from the respective operator page (Name, Side, Stats, and Loadout).

# %%
def getName(soup):
    name = (
        soup.find(
            "div",
            attrs={"class": "operator__header__icons__names"},
        )
        .find("h1")
        .text
    )
    return name.upper()

# %%
def getSide(soup):
    side = (
        soup.find(
            "div",
            attrs={"class": "operator__header__side__detail"},
        )
        .find("span")
        .text
    )
    return side.upper()

# %%
def getStats(soup):
    stats = {}
    stats_divs = soup.find(
        "div",
        attrs={"class": "operator__header__stats"},
    )
    for stat in stats_divs:
        stat_title = (
            stat.find("div", attrs={"class": "operator__header__stat__title"})
            .find("span")
            .text
        )

        stat_title = stat_title.lower()

        rater = stat.find(
            "div",
            attrs={"class": "react-rater"},
        )

        filled_points = rater.find_all(
            "div", attrs={"class": "react-rater-star is-disabled is-active"}
        )
        stats.update({stat_title: len(filled_points)})
    return stats

# %%
def getLoadout(soup):
    loadout = {}
    loadout_divs = soup.find_all("div", attrs={"class": "operator__loadout__category"})

    for i, div in enumerate(loadout_divs):
        loadout_title = (
            div.find("h2", attrs={"class": "operator__loadout__category__title"})
            .find("span")
            .text
        )

        loadout_title = loadout_title.lower()
        loadout_title = loadout_title.replace(" ", "_")

        if (
            loadout_title == "primary_weapon"
            or loadout_title == "secondary_weapon"
            or loadout_title == "gadget"
        ):
            for i in range(1, 4):
                loadout.update({f"{loadout_title}_{i}": None})

        items_div = div.find_all("div", attrs={"class": "operator__loadout__weapon"})
        for idx, item in enumerate(items_div):
            item_name = item.find("p").text
            loadout.update({f"{loadout_title}_{str(idx + 1)}": item_name.upper()})
    return loadout

# %% [markdown]
# ### Function to request page and return operator information

# %%
def scrape_operator(operator_name):
    url = f"https://www.ubisoft.com/en-ca/game/rainbow-six/siege/game-info/operators/{operator_name}"
    HEADERS = {
        "User-Agent": USER_AGENT,
        "Accept-Language": "en-US en;q=0.5",
    }
    page = requests.get(url, headers=HEADERS).text
    soup = BeautifulSoup(page, "html.parser")
    operator_information = {}

    name = getName(soup)
    side = getSide(soup)
    stats = getStats(soup)
    loadout = getLoadout(soup)

    operator_information.update({"name": name, "side": side})
    operator_information.update(stats)
    operator_information.update(loadout)

    return operator_information

# %% [markdown]
# Iterate through all of the operator names and append operator information extracted from web page to a list

# %%
operator_data = []
for name in operator_names:
    operator_data.append(scrape_operator(name))
operator_data
# Out:
# [{'name': 'LION',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': '417',
#   'primary_weapon_2': 'SG-CQB',
#   'primary_weapon_3': 'V308',
#   'secondary_weapon_1': 'LFP586',
#   'secondary_weapon_2': 'P9',
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'STUN GRENADE',
#   'unique_ability_1': 'EE-ONE-D'},
#  {'name': 'AMARU',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'G8A1',
#   'primary_weapon_2': 'SUPERNOVA',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'GONNE-6',
#   'secondary_weapon_2': 'SMG-11',
#   'secondary_weapon_3': 'ITA12S',
#   'gadget_1': 'STUN GRENADE',
#   'gadget_2': 'HARD BREACH CHARGE',
#   'gadget_3': None,
#   'unique_ability_1': 'GARRA HOOK'},
#  {'name': 'GOYO',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'VECTOR .45 ACP',
#   'primary_weapon_2': 'TCSG12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P229',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'BULLETPROOF CAMERA',
#   'gadget_3': 'IMPACT GRENADE',
#   'unique_ability_1': 'VOLCÁN CANISTER'},
#  {'name': 'NØKK',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': 'FMG-9',
#   'primary_weapon_2': 'SIX12 SD',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'D-50',
#   'secondary_weapon_3': None,
#   'gadget_1': 'HARD BREACH CHARGE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'HEL PRESENCE REDUCTION'},
#  {'name': 'WARDEN',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 2,
#   'primary_weapon_1': 'M590A1',
#   'primary_weapon_2': 'MPX',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P-10C',
#   'secondary_weapon_2': 'SMG-12',
#   'secondary_weapon_3': None,
#   'gadget_1': 'DEPLOYABLE SHIELD',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': 'OBSERVATION BLOCKER',
#   'unique_ability_1': 'GLANCE SMART GLASSES'},
#  {'name': 'MOZZIE',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'COMMANDO 9',
#   'primary_weapon_2': 'P10 RONI',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'SDP 9MM',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': None,
#   'unique_ability_1': 'PEST LAUNCHER'},
#  {'name': 'GRIDLOCK',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'F90',
#   'primary_weapon_2': 'M249 SAW',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'SUPER SHORTY',
#   'secondary_weapon_2': 'SDP 9MM',
#   'secondary_weapon_3': None,
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'TRAX STINGERS'},
#  {'name': 'NOMAD',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': 'AK-74M',
#   'primary_weapon_2': 'ARX200',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'PRB92',
#   'secondary_weapon_2': '.44 MAG SEMI-AUTO',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'STUN GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'AIRJAB LAUNCHER'},
#  {'name': 'KAID',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 2,
#   'primary_weapon_1': 'AUG A3',
#   'primary_weapon_2': 'TCSG12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '.44 MAG SEMI-AUTO',
#   'secondary_weapon_2': 'LFP586',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': 'OBSERVATION BLOCKER',
#   'unique_ability_1': '"RTILA" ELECTROCLAW'},
#  {'name': 'CLASH',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 3,
#   'primary_weapon_1': 'CCE SHIELD',
#   'primary_weapon_2': None,
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P-10C',
#   'secondary_weapon_2': 'SPSMG9',
#   'secondary_weapon_3': 'SUPER SHORTY',
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'DEPLOYABLE SHIELD',
#   'gadget_3': 'IMPACT GRENADE',
#   'unique_ability_1': 'CCE SHIELD'},
#  {'name': 'MAVERICK',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 2,
#   'primary_weapon_1': 'AR-15.50',
#   'primary_weapon_2': 'M4',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '1911 TACOPS',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'SMOKE GRENADE',
#   'gadget_3': 'STUN GRENADE',
#   'unique_ability_1': 'BREACHING TORCH'},
#  {'name': 'MAESTRO',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 2,
#   'primary_weapon_1': 'ALDA 5.56',
#   'primary_weapon_2': 'ACS12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'KERATOS .357',
#   'secondary_weapon_2': 'BAILIFF 410',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'IMPACT GRENADE',
#   'gadget_3': 'OBSERVATION BLOCKER',
#   'unique_ability_1': 'EVIL EYE'},
#  {'name': 'ALIBI',
#   'side': 'DEFENDER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 3,
#   'primary_weapon_1': 'MX4 STORM',
#   'primary_weapon_2': 'ACS12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'KERATOS .357',
#   'secondary_weapon_2': 'BAILIFF 410',
#   'secondary_weapon_3': None,
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'OBSERVATION BLOCKER',
#   'gadget_3': None,
#   'unique_ability_1': 'PRISMA'},
#  {'name': 'FINKA',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': '6P41',
#   'primary_weapon_2': 'SASG-12',
#   'primary_weapon_3': 'SPEAR .308',
#   'secondary_weapon_1': 'GSH-18',
#   'secondary_weapon_2': 'PMM',
#   'secondary_weapon_3': None,
#   'gadget_1': 'FRAG GRENADE',
#   'gadget_2': 'SMOKE GRENADE',
#   'gadget_3': 'STUN GRENADE',
#   'unique_ability_1': 'ADRENAL SURGE'},
#  {'name': 'VIGIL',
#   'side': 'DEFENDER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 3,
#   'primary_weapon_1': 'K1A',
#   'primary_weapon_2': 'BOSG.12.2',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'C75 AUTO',
#   'secondary_weapon_2': 'SMG-12',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'IMPACT GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'ERC-7'},
#  {'name': 'DOKKAEBI',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 2,
#   'primary_weapon_1': 'MK 14 EBR',
#   'primary_weapon_2': 'BOSG.12.2',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'GONNE-6',
#   'secondary_weapon_2': 'SMG-12',
#   'secondary_weapon_3': 'C75 AUTO',
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'STUN GRENADE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'LOGIC BOMB'},
#  {'name': 'ZOFIA',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'LMG-E',
#   'primary_weapon_2': 'M762',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'RG15',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'KS79 LIFELINE'},
#  {'name': 'ELA',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'SCORPION EVO 3 A1',
#   'primary_weapon_2': 'FO-12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'RG15',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'DEPLOYABLE SHIELD',
#   'gadget_3': 'IMPACT GRENADE',
#   'unique_ability_1': 'GRZMOT MINE'},
#  {'name': 'YING',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'T-95 LSW',
#   'primary_weapon_2': 'SIX12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'Q-929',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'HARD BREACH CHARGE',
#   'gadget_2': 'SMOKE GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'CANDELA'},
#  {'name': 'LESION',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'SIX12 SD',
#   'primary_weapon_2': 'T-5 SMG',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'Q-929',
#   'secondary_weapon_2': 'SUPER SHORTY',
#   'secondary_weapon_3': None,
#   'gadget_1': 'IMPACT GRENADE',
#   'gadget_2': 'BULLETPROOF CAMERA',
#   'gadget_3': None,
#   'unique_ability_1': 'GU'},
#  {'name': 'MIRA',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 3,
#   'primary_weapon_1': 'VECTOR .45 ACP',
#   'primary_weapon_2': 'ITA12L',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'USP40',
#   'secondary_weapon_2': 'ITA12S',
#   'secondary_weapon_3': None,
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': None,
#   'unique_ability_1': 'BLACK MIRROR'},
#  {'name': 'JACKAL',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': 'C7E',
#   'primary_weapon_2': 'PDW9',
#   'primary_weapon_3': 'ITA12L',
#   'secondary_weapon_1': 'USP40',
#   'secondary_weapon_2': 'ITA12S',
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'SMOKE GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'EYENOX MODEL III'},
#  {'name': 'HIBANA',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 1,
#   'primary_weapon_1': 'TYPE-89',
#   'primary_weapon_2': 'SUPERNOVA',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P229',
#   'secondary_weapon_2': 'BEARING 9',
#   'secondary_weapon_3': None,
#   'gadget_1': 'STUN GRENADE',
#   'gadget_2': 'BREACH CHARGE',
#   'gadget_3': None,
#   'unique_ability_1': 'X-KAIROS'},
#  {'name': 'ECHO',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 3,
#   'primary_weapon_1': 'MP5SD',
#   'primary_weapon_2': 'SUPERNOVA',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'BEARING 9',
#   'secondary_weapon_2': 'P229',
#   'secondary_weapon_3': None,
#   'gadget_1': 'IMPACT GRENADE',
#   'gadget_2': 'DEPLOYABLE SHIELD',
#   'gadget_3': None,
#   'unique_ability_1': 'YOKAI'},
#  {'name': 'CAVEIRA',
#   'side': 'DEFENDER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 3,
#   'primary_weapon_1': 'M12',
#   'primary_weapon_2': 'SPAS-15',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'LUISON',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'IMPACT GRENADE',
#   'gadget_3': 'OBSERVATION BLOCKER',
#   'unique_ability_1': 'SILENT STEP'},
#  {'name': 'CAPITÃO',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 2,
#   'primary_weapon_1': 'M249',
#   'primary_weapon_2': 'PARA-308',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'GONNE-6',
#   'secondary_weapon_2': 'PRB92',
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'HARD BREACH CHARGE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'TACTICAL CROSSBOW'},
#  {'name': 'BLACKBEARD',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'MK17 CQB',
#   'primary_weapon_2': 'SR-25',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'D-50',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'STUN GRENADE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'CLAYMORE',
#   'unique_ability_1': 'RIFLE-SHIELD'},
#  {'name': 'VALKYRIE',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'MPX',
#   'primary_weapon_2': 'SPAS-12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'D-50',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'IMPACT GRENADE',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': None,
#   'unique_ability_1': 'BLACK EYE'},
#  {'name': 'BUCK',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'C8-SFW',
#   'primary_weapon_2': 'CAMRS',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'MK1 9MM',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'HARD BREACH CHARGE',
#   'gadget_2': 'STUN GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'SKELETON KEY'},
#  {'name': 'FROST',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'SUPER 90',
#   'primary_weapon_2': '9MM C1',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'MK1 9MM',
#   'secondary_weapon_2': 'ITA12S',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'DEPLOYABLE SHIELD',
#   'gadget_3': None,
#   'unique_ability_1': 'WELCOME MAT'},
#  {'name': 'MUTE',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'MP5K',
#   'primary_weapon_2': 'M590A1',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P226 MK 25',
#   'secondary_weapon_2': 'SMG-11',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': None,
#   'unique_ability_1': 'SIGNAL DISRUPTOR'},
#  {'name': 'SLEDGE',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'L85A2',
#   'primary_weapon_2': 'M590A1',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P226 MK 25',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'FRAG GRENADE',
#   'gadget_2': 'STUN GRENADE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'BREACHING HAMMER'},
#  {'name': 'SMOKE',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'M590A1',
#   'primary_weapon_2': 'FMG-9',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P226 MK 25',
#   'secondary_weapon_2': 'SMG-11',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'PROXIMITY ALARM',
#   'gadget_3': None,
#   'unique_ability_1': 'REMOTE GAS GRENADE'},
#  {'name': 'THATCHER',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'AR33',
#   'primary_weapon_2': 'L85A2',
#   'primary_weapon_3': 'M590A1',
#   'secondary_weapon_1': 'P226 MK 25',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'EMP GRENADE'},
#  {'name': 'ASH',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 2,
#   'primary_weapon_1': 'G36C',
#   'primary_weapon_2': 'R4-C',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'M45 MEUSOC',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'BREACHING ROUND'},
#  {'name': 'CASTLE',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'UMP45',
#   'primary_weapon_2': 'M1014',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'SUPER SHORTY',
#   'secondary_weapon_3': 'M45 MEUSOC',
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'BULLETPROOF CAMERA',
#   'gadget_3': None,
#   'unique_ability_1': 'ARMOR PANEL'},
#  {'name': 'PULSE',
#   'side': 'DEFENDER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 3,
#   'primary_weapon_1': 'UMP45',
#   'primary_weapon_2': 'M1014',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'M45 MEUSOC',
#   'secondary_weapon_3': None,
#   'gadget_1': 'NITRO CELL',
#   'gadget_2': 'DEPLOYABLE SHIELD',
#   'gadget_3': 'OBSERVATION BLOCKER',
#   'unique_ability_1': 'CARDIAC SENSOR'},
#  {'name': 'THERMITE',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'M1014',
#   'primary_weapon_2': '556XI',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'M45 MEUSOC',
#   'secondary_weapon_3': None,
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'STUN GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'EXOTHERMIC CHARGE'},
#  {'name': 'MONTAGNE',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 3,
#   'primary_weapon_1': 'LE ROC SHIELD',
#   'primary_weapon_2': None,
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P9',
#   'secondary_weapon_2': 'LFP586',
#   'secondary_weapon_3': None,
#   'gadget_1': 'HARD BREACH CHARGE',
#   'gadget_2': 'SMOKE GRENADE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'LE ROC SHIELD'},
#  {'name': 'TWITCH',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'F2',
#   'primary_weapon_2': '417',
#   'primary_weapon_3': 'SG-CQB',
#   'secondary_weapon_1': 'P9',
#   'secondary_weapon_2': 'LFP586',
#   'secondary_weapon_3': None,
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'SHOCK DRONE'},
#  {'name': 'DOC',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'MP5',
#   'primary_weapon_2': 'P90',
#   'primary_weapon_3': 'SG-CQB',
#   'secondary_weapon_1': 'P9',
#   'secondary_weapon_2': 'LFP586',
#   'secondary_weapon_3': 'BAILIFF 410',
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'BARBED WIRE',
#   'gadget_3': None,
#   'unique_ability_1': 'STIM PISTOL'},
#  {'name': 'ROOK',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'MP5',
#   'primary_weapon_2': 'P90',
#   'primary_weapon_3': 'SG-CQB',
#   'secondary_weapon_1': 'P9',
#   'secondary_weapon_2': 'LFP586',
#   'secondary_weapon_3': None,
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'IMPACT GRENADE',
#   'gadget_3': 'OBSERVATION BLOCKER',
#   'unique_ability_1': 'ARMOR PACK'},
#  {'name': 'JÄGER',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'M870',
#   'primary_weapon_2': '416-C CARBINE',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P12',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'OBSERVATION BLOCKER',
#   'gadget_3': None,
#   'unique_ability_1': 'ACTIVE DEFENSE'},
#  {'name': 'BANDIT',
#   'side': 'DEFENDER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 1,
#   'primary_weapon_1': 'MP7',
#   'primary_weapon_2': 'M870',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P12',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'NITRO CELL',
#   'gadget_3': None,
#   'unique_ability_1': 'SHOCK WIRE'},
#  {'name': 'BLITZ',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': 'G52-TACTICAL SHIELD',
#   'primary_weapon_2': None,
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P12',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'BREACH CHARGE',
#   'gadget_3': None,
#   'unique_ability_1': 'G52-TACTICAL SHIELD'},
#  {'name': 'IQ',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 3,
#   'primary_weapon_1': 'AUG A2',
#   'primary_weapon_2': '552 COMMANDO',
#   'primary_weapon_3': 'G8A1',
#   'secondary_weapon_1': 'P12',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'CLAYMORE',
#   'unique_ability_1': 'ELECTRONICS DETECTOR'},
#  {'name': 'FUZE',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'AK-12',
#   'primary_weapon_2': '6P41',
#   'primary_weapon_3': 'BALLISTIC SHIELD',
#   'secondary_weapon_1': 'PMM',
#   'secondary_weapon_2': 'GSH-18',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'HARD BREACH CHARGE',
#   'gadget_3': 'SMOKE GRENADE',
#   'unique_ability_1': 'CLUSTER CHARGE'},
#  {'name': 'GLAZ',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 2,
#   'primary_weapon_1': 'OTS-03',
#   'primary_weapon_2': None,
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'PMM',
#   'secondary_weapon_2': 'GONNE-6',
#   'secondary_weapon_3': 'BEARING 9',
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'CLAYMORE',
#   'unique_ability_1': 'FLIP SIGHT'},
#  {'name': 'TACHANKA',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'DP27',
#   'primary_weapon_2': '9X19VSN',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'PMM',
#   'secondary_weapon_2': 'GSH-18',
#   'secondary_weapon_3': 'BEARING 9',
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'PROXIMITY ALARM',
#   'gadget_3': 'DEPLOYABLE SHIELD',
#   'unique_ability_1': 'SHUMIKHA LAUNCHER'},
#  {'name': 'KAPKAN',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': '9X19VSN',
#   'primary_weapon_2': 'SASG-12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'PMM',
#   'secondary_weapon_2': 'GSH-18',
#   'secondary_weapon_3': None,
#   'gadget_1': 'NITRO CELL',
#   'gadget_2': 'BULLETPROOF CAMERA',
#   'gadget_3': None,
#   'unique_ability_1': 'ENTRY DENIAL DEVICE'},
#  {'name': 'KALI',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'CSRX 300',
#   'primary_weapon_2': None,
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'SPSMG9',
#   'secondary_weapon_2': 'C75 AUTO',
#   'secondary_weapon_3': 'P226 MK 25',
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'LV EXPLOSIVE LANCE'},
#  {'name': 'WAMAI',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'AUG A2',
#   'primary_weapon_2': 'MP5K',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P12',
#   'secondary_weapon_2': 'KERATOS .357',
#   'secondary_weapon_3': None,
#   'gadget_1': 'PROXIMITY ALARM',
#   'gadget_2': 'IMPACT GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'MAG-NET SYSTEM'},
#  {'name': 'IANA',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'ARX200',
#   'primary_weapon_2': 'G36C',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'GONNE-6',
#   'secondary_weapon_2': 'MK1 9MM',
#   'secondary_weapon_3': None,
#   'gadget_1': 'IMPACT EMP GRENADE',
#   'gadget_2': 'SMOKE GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'GEMINI REPLICATOR'},
#  {'name': 'ORYX',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'SPAS-12',
#   'primary_weapon_2': 'T-5 SMG',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'BAILIFF 410',
#   'secondary_weapon_2': 'USP40',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'PROXIMITY ALARM',
#   'gadget_3': None,
#   'unique_ability_1': 'REMAH DASH'},
#  {'name': 'ACE',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'AK-12',
#   'primary_weapon_2': 'M1014',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P9',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'S.E.L.M.A. AQUA BREACHER'},
#  {'name': 'MELUSI',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 1,
#   'primary_weapon_1': 'MP5',
#   'primary_weapon_2': 'SUPER 90',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'ITA12S',
#   'secondary_weapon_2': 'RG15',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'IMPACT GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'BANSHEE SONIC DEFENSE'},
#  {'name': 'ZERO',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 1,
#   'primary_weapon_1': 'MP7',
#   'primary_weapon_2': 'SC3000K',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'GONNE-6',
#   'secondary_weapon_3': None,
#   'gadget_1': 'HARD BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'ARGUS LAUNCHER'},
#  {'name': 'ARUNI',
#   'side': 'DEFENDER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 2,
#   'primary_weapon_1': 'P10 RONI',
#   'primary_weapon_2': 'MK 14 EBR',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'PRB92',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'BARBED WIRE',
#   'gadget_3': None,
#   'unique_ability_1': 'SURYA GATE'},
#  {'name': 'FLORES',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'AR33',
#   'primary_weapon_2': 'SR-25',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'GSH-18',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'STUN GRENADE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'RCE-RATERO CHARGE'},
#  {'name': 'THUNDERBIRD',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'SPAS-15',
#   'primary_weapon_2': 'SPEAR .308',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'BEARING 9',
#   'secondary_weapon_2': 'Q-929',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'BULLETPROOF CAMERA',
#   'gadget_3': 'DEPLOYABLE SHIELD',
#   'unique_ability_1': 'KÓNA STATION'},
#  {'name': 'OSA',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 2,
#   'primary_weapon_1': '556XI',
#   'primary_weapon_2': 'PDW9',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'PMM',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'TALON-8 CLEAR SHIELD'},
#  {'name': 'THORN',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'UZK50GI',
#   'primary_weapon_2': 'M870',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '1911 TACOPS',
#   'secondary_weapon_2': 'C75 AUTO',
#   'secondary_weapon_3': None,
#   'gadget_1': 'DEPLOYABLE SHIELD',
#   'gadget_2': 'BARBED WIRE',
#   'gadget_3': None,
#   'unique_ability_1': 'RAZORBLOOM SHELL'},
#  {'name': 'AZAMI ',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': '9X19SVN',
#   'primary_weapon_2': 'ACS12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'D-50',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'IMPACT GRENADE',
#   'gadget_2': 'BARBED WIRE',
#   'gadget_3': None,
#   'unique_ability_1': 'KIBA BARRIER'},
#  {'name': 'SENS',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 2,
#   'primary_weapon_1': '417',
#   'primary_weapon_2': 'POF9',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'SDP 9MM',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'FRAG GRENADE',
#   'gadget_3': 'HARD BREACH CHARGE',
#   'unique_ability_1': 'R.O.U. PROJECTOR SYSTEM'},
#  {'name': 'GRIM',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 1,
#   'primary_weapon_1': '552 COMMANDO',
#   'primary_weapon_2': 'SG-CQB',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'BAILIFF 410',
#   'secondary_weapon_2': 'P229',
#   'secondary_weapon_3': None,
#   'gadget_1': 'CLAYMORE',
#   'gadget_2': 'HARD BREACH CHARGE',
#   'gadget_3': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'KAWAN HIVE LAUNCHER'},
#  {'name': 'SOLIS',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': 'ITA12L',
#   'primary_weapon_2': 'P90',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'SMG-11',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'PROXIMITY ALARM',
#   'gadget_3': None,
#   'unique_ability_1': 'SPEC-IO ELECTRO-SENSOR'},
#  {'name': 'BRAVA',
#   'side': 'ATTACKER',
#   'health': 1,
#   'speed': 3,
#   'difficulty': 3,
#   'primary_weapon_1': 'PARA-308',
#   'primary_weapon_2': 'CAMRS',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'USP40',
#   'secondary_weapon_2': 'SUPER SHORTY',
#   'secondary_weapon_3': None,
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': None,
#   'unique_ability_1': 'KLUDGE DRONE'},
#  {'name': 'FENRIR',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 3,
#   'primary_weapon_1': 'MP7',
#   'primary_weapon_2': 'SASG-12',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'BAILIFF 410',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BULLETPROOF CAMERA',
#   'gadget_2': 'OBSERVATION BLOCKER',
#   'gadget_3': None,
#   'unique_ability_1': 'F-NATT DREAD MINE'},
#  {'name': 'RAM',
#   'side': 'ATTACKER',
#   'health': 3,
#   'speed': 1,
#   'difficulty': 2,
#   'primary_weapon_1': 'LMG-E',
#   'primary_weapon_2': 'R4-C',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'ITA12S',
#   'secondary_weapon_2': 'MK1 9MM',
#   'secondary_weapon_3': None,
#   'gadget_1': 'SMOKE GRENADE',
#   'gadget_2': 'STUN GRENADE',
#   'gadget_3': None,
#   'unique_ability_1': 'BU-GI AUTO BREACHER'},
#  {'name': 'TUBARÃO',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'MPX',
#   'primary_weapon_2': 'AR-15.50',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P226 MK 25',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'NITRO CELL',
#   'gadget_2': 'PROXIMITY ALARM',
#   'gadget_3': None,
#   'unique_ability_1': 'ZOTO CANISTER'},
#  {'name': 'DEIMOS',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'AK-74M',
#   'primary_weapon_2': 'M590A1',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '.44 VENDETTA',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'FRAG GRENADE',
#   'gadget_2': 'HARD BREACH CHARGE',
#   'gadget_3': None,
#   'unique_ability_1': 'DEATHMARK TRACKER'},
#  {'name': 'STRIKER',
#   'side': 'ATTACKER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'M4',
#   'primary_weapon_2': 'M249',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': '5.7 USG',
#   'secondary_weapon_2': 'ITA12S',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BREACH CHARGE',
#   'gadget_2': 'CLAYMORE',
#   'gadget_3': 'FRAG GRENADE',
#   'gadget_4': 'HARD BREACH CHARGE',
#   'gadget_5': 'SMOKE GRENADE',
#   'gadget_6': 'STUN GRENADE',
#   'gadget_7': 'IMPACT EMP GRENADE',
#   'unique_ability_1': 'GADGET KIT'},
#  {'name': 'SENTRY',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 1,
#   'primary_weapon_1': 'COMMANDO 9',
#   'primary_weapon_2': 'M870',
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'C75 AUTO',
#   'secondary_weapon_2': 'SUPER SHORTY',
#   'secondary_weapon_3': None,
#   'gadget_1': 'BARBED WIRE',
#   'gadget_2': 'BULLETPROOF CAMERA',
#   'gadget_3': 'DEPLOYABLE SHIELD',
#   'gadget_4': 'OBSERVATION BLOCKER',
#   'gadget_5': 'IMPACT GRENADE',
#   'gadget_6': 'NITRO CELL',
#   'gadget_7': 'PROXIMITY ALARM',
#   'unique_ability_1': 'GADGET KIT'},
#  {'name': 'SKOPÓS',
#   'side': 'DEFENDER',
#   'health': 2,
#   'speed': 2,
#   'difficulty': 2,
#   'primary_weapon_1': 'PCX-33',
#   'primary_weapon_2': None,
#   'primary_weapon_3': None,
#   'secondary_weapon_1': 'P229',
#   'secondary_weapon_2': None,
#   'secondary_weapon_3': None,
#   'gadget_1': 'IMPACT GRENADE',
#   'gadget_2': 'PROXIMITY ALARM',
#   'gadget_3': None,
#   'unique_ability_1': 'V10 PANTHEON SHELLS'}]

# %% [markdown]
# Convert list of data to a dataframe

# %%
df = pd.DataFrame(operator_data)
df
# Out:
#        name      side  health  speed  difficulty primary_weapon_1  \
# 0      LION  ATTACKER       2      2           1              417
# 1     AMARU  ATTACKER       2      2           2             G8A1
# 2      GOYO  DEFENDER       2      2           2   VECTOR .45 ACP
# 3      NØKK  ATTACKER       2      2           3            FMG-9
# 4    WARDEN  DEFENDER       3      1           2           M590A1
# ..      ...       ...     ...    ...         ...              ...
# 69  TUBARÃO  DEFENDER       2      2           2              MPX
# 70   DEIMOS  ATTACKER       2      2           2           AK-74M
# 71  STRIKER  ATTACKER       2      2           1               M4
# 72   SENTRY  DEFENDER       2      2           1       COMMANDO 9
# 73   SKOPÓS  DEFENDER       2      2           2           PCX-33
#
#    primary_weapon_2 primary_weapon_3 secondary_weapon_1 secondary_weapon_2  \
# 0            SG-CQB             V308             LFP586                 P9
# 1         SUPERNOVA             None            GONNE-6             SMG-11
# 2            TCSG12             None               P229               None
# 3          SIX12 SD             None            5.7 USG               D-50
# 4               MPX             None              P-10C             SMG-12
# ..              ...              ...                ...                ...
# 69         AR-15.50             None         P226 MK 25               None
# 70           M590A1             None       .44 VENDETTA               None
# 71             M249             None            5.7 USG             ITA12S
# 72             M870             None           C75 AUTO       SUPER SHORTY
# 73             None             None               P229               None
#
#    secondary_weapon_3            gadget_1            gadget_2  \
# 0                None            CLAYMORE        FRAG GRENADE
# 1              ITA12S        STUN GRENADE  HARD BREACH CHARGE
# 2                None     PROXIMITY ALARM  BULLETPROOF CAMERA
# 3                None  HARD BREACH CHARGE        FRAG GRENADE
# 4                None   DEPLOYABLE SHIELD          NITRO CELL
# ..                ...                 ...                 ...
# 69               None          NITRO CELL     PROXIMITY ALARM
# 70               None        FRAG GRENADE  HARD BREACH CHARGE
# 71               None       BREACH CHARGE            CLAYMORE
# 72               None         BARBED WIRE  BULLETPROOF CAMERA
# 73               None      IMPACT GRENADE     PROXIMITY ALARM
#
#                gadget_3        unique_ability_1             gadget_4  \
# 0          STUN GRENADE                EE-ONE-D                  NaN
# 1                  None              GARRA HOOK                  NaN
# 2        IMPACT GRENADE         VOLCÁN CANISTER                  NaN
# 3    IMPACT EMP GRENADE  HEL PRESENCE REDUCTION                  NaN
# 4   OBSERVATION BLOCKER    GLANCE SMART GLASSES                  NaN
# ..                  ...                     ...                  ...
# 69                 None           ZOTO CANISTER                  NaN
# 70                 None       DEATHMARK TRACKER                  NaN
# 71         FRAG GRENADE              GADGET KIT   HARD BREACH CHARGE
# 72    DEPLOYABLE SHIELD              GADGET KIT  OBSERVATION BLOCKER
# 73                 None     V10 PANTHEON SHELLS                  NaN
#
#           gadget_5      gadget_6            gadget_7
# 0              NaN           NaN                 NaN
# 1              NaN           NaN                 NaN
# 2              NaN           NaN                 NaN
# 3              NaN           NaN                 NaN
# 4              NaN           NaN                 NaN
# ..             ...           ...                 ...
# 69             NaN           NaN                 NaN
# 70             NaN           NaN                 NaN
# 71   SMOKE GRENADE  STUN GRENADE  IMPACT EMP GRENADE
# 72  IMPACT GRENADE    NITRO CELL     PROXIMITY ALARM
# 73             NaN           NaN                 NaN
#
# [74 rows x 19 columns]

# %% [markdown]
# Convert dataframe to .csv file

# %%
df.to_csv("r6_operator_data.csv", encoding="utf-8")
